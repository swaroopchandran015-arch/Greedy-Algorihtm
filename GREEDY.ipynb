# %% [markdown]
# <a href="https://colab.research.google.com/github/swaroopchandran015-arch/Greedy-Algorihtm/blob/main/GREEDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#best first

import heapq

def greedy_best_first_search(graph, heuristic, start, goal):
    priority_queue = []

    # (heuristic value, current node)
    heapq.heappush(priority_queue, (heuristic[start], start))

    visited = set()

    while priority_queue:
        h, current = heapq.heappop(priority_queue)

        if current in visited:
            continue

        print("Visiting:", current)
        visited.add(current)

        # Goal reached
        if current == goal:
            print("Goal reached!")
            return

        # Add neighbouring nodes
        for neighbour in graph[current]:
            if neighbour not in visited:
                heapq.heappush(
                    priority_queue,
                    (heuristic[neighbour], neighbour)
                )

    print("Goal not found")


# Graph
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

# Heuristic values
heuristic = {
    'A': 6,
    'B': 4,
    'C': 5,
    'D': 3,
    'E': 2,
    'F': 4,
    'G': 0
}

# Run algorithm
greedy_best_first_search(graph, heuristic, 'A', 'G')
# Out:
# Visiting: A
# Visiting: B
# Visiting: E
# Visiting: G
# Goal reached!

# %%
#BFS

from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    visited.add(start)

    while queue:
        node = queue.popleft()
        print(node, end=" ")

        for neighbour in graph[node]:
            if neighbour not in visited:
                visited.add(neighbour)
                queue.append(neighbour)


graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

bfs(graph, 'A')
# Out:
# A B C D E F

# %%
#DFS

def dfs(graph, node, visited):
    visited.add(node)

    print(node, end=" ")

    for neighbour in graph[node]:
        if neighbour not in visited:
            dfs(graph, neighbour, visited)


graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

visited = set()

dfs(graph, 'A', visited)
# Out:
# A B D E C F
